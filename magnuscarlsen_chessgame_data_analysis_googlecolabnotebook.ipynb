# %% [markdown]
# #**Magnus Carlsen Chess Games Data Analysis**

# %% [markdown]
# ###Import some Python libraries for Analyze data

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ###Now we install chess library for collect data from pgn file

# %%
pip install python-chess pandas
# Out:
# Collecting python-chess
#   Downloading python_chess-1.999-py3-none-any.whl.metadata (776 bytes)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (2.2.2)
# Collecting chess<2,>=1 (from python-chess)
#   Downloading chess-1.10.0-py3-none-any.whl.metadata (19 kB)
# Requirement already satisfied: numpy>=1.22.4 in /usr/local/lib/python3.10/dist-packages (from pandas) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas) (2024.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Downloading python_chess-1.999-py3-none-any.whl (1.4 kB)
# Downloading chess-1.10.0-py3-none-any.whl (154 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 154.4/154.4 kB 2.3 MB/s eta 0:00:00
# Installing collected packages: chess, python-chess
# Successfully installed chess-1.10.0 python-chess-1.999

# %% [markdown]
# ###Here we process on data to collect data from pgn file and transform in to csv file for further process

# %%
import chess.pgn
import csv

# Function to parse a single game
def parse_pgn(pgn_game):
    # Extracting basic metadata
    game = chess.pgn.read_game(pgn_game)
    if game is None:
        return None

    headers = game.headers
    moves = []
    board = game.board()

    # Extract and record all the moves in SAN (Standard Algebraic Notation)
    for move in game.mainline_moves():
        san_move = board.san(move)  # Convert move to SAN
        moves.append(san_move)
        board.push(move)  # Make the move on the board

    # Return the game data as a dictionary
    return {
        "Event": headers.get("Event", ""),
        "Site": headers.get("Site", ""),
        "Date": headers.get("Date", ""),
        "Round": headers.get("Round", ""),
        "White": headers.get("White", ""),
        "Black": headers.get("Black", ""),
        "Result": headers.get("Result", ""),
        "CurrentPosition": headers.get("CurrentPosition", ""),
        "Timezone": headers.get("Timezone", ""),
        "ECO": headers.get("ECO", ""),
        "ECOUrl": headers.get("ECOUrl", ""),
        "UTCDate": headers.get("UTCDate", ""),
        "UTCTime": headers.get("UTCTime", ""),
        "WhiteElo": headers.get("WhiteElo", ""),
        "BlackElo": headers.get("BlackElo", ""),
        "TimeControl": headers.get("TimeControl", ""),
        "Termination": headers.get("Termination", ""),
        "StartTime": headers.get("StartTime", ""),
        "EndDate": headers.get("EndDate", ""),
        "EndTime": headers.get("EndTime", ""),
        "Link": headers.get("Link", ""),
        "Moves": " ".join(moves)  # Join the list of moves as a single string
    }

# Function to process the entire PGN file and write to CSV
def process_pgn_file(pgn_file_path, csv_file_path):
    # Open the PGN file and CSV output file
    with open(pgn_file_path, 'r') as pgn_file, open(csv_file_path, 'w', newline='', encoding='utf-8') as csvfile:
        csv_writer = csv.writer(csvfile)

        # Write the header to the CSV file
        csv_writer.writerow([
            "Event", "Site", "Date", "Round", "White", "Black", "Result",
            "CurrentPosition", "Timezone", "ECO", "ECOUrl", "UTCDate", "UTCTime",
            "WhiteElo", "BlackElo", "TimeControl", "Termination", "StartTime",
            "EndDate", "EndTime", "Link", "Moves"
        ])

        # Parse the PGN file game by game
        while True:
            game_data = parse_pgn(pgn_file)
            if game_data is None:
                break  # No more games to process

            # Write the game data to the CSV file
            csv_writer.writerow([
                game_data["Event"],
                game_data["Site"],
                game_data["Date"],
                game_data["Round"],
                game_data["White"],
                game_data["Black"],
                game_data["Result"],
                game_data["CurrentPosition"],
                game_data["Timezone"],
                game_data["ECO"],
                game_data["ECOUrl"],
                game_data["UTCDate"],
                game_data["UTCTime"],
                game_data["WhiteElo"],
                game_data["BlackElo"],
                game_data["TimeControl"],
                game_data["Termination"],
                game_data["StartTime"],
                game_data["EndDate"],
                game_data["EndTime"],
                game_data["Link"],
                game_data["Moves"]
            ])

# Specify your PGN file and the output CSV file path
pgn_file_path = '/content/sample_data/MagnusCarlsen_all_games.pgn'  # Your PGN file
csv_file_path = '/content/sample_data/chess_games3.csv'  # Output CSV file

# Run the PGN file processing function
process_pgn_file(pgn_file_path, csv_file_path)

# %% [markdown]
# ###Convert csv file in to DataFrame

# %%
df = pd.read_csv("/content/sample_data/chess_games3.csv")
df
# Out:
#            Event       Site        Date Round             White  \
# 0     Live Chess  Chess.com  2014.12.14     -     MagnusCarlsen
# 1     Live Chess  Chess.com  2014.12.14     -     MagnusCarlsen
# 2     Live Chess  Chess.com  2014.12.14     -     MagnusCarlsen
# 3     Live Chess  Chess.com  2014.12.14     -     MagnusCarlsen
# 4     Live Chess  Chess.com  2014.12.14     -     MagnusCarlsen
# ...          ...        ...         ...   ...               ...
# 5760  Live Chess  Chess.com  2024.09.21     -  Chesswizard_2007
# 5761  Live Chess  Chess.com  2024.09.21     -     MagnusCarlsen
# 5762  Live Chess  Chess.com  2024.09.21     -     MagnusCarlsen
# 5763  Live Chess  Chess.com  2024.09.21     -  Chesswizard_2007
# 5764  Live Chess  Chess.com  2024.09.21     -     MagnusCarlsen
#
#                  Black   Result  \
# 0          RainnWilson      1-0
# 1             solskytz      1-0
# 2         Tildenbeatsu      1-0
# 3               mtmnfy      1-0
# 4      stepanosinovsky      0-1
# ...                ...      ...
# 5760     MagnusCarlsen      0-1
# 5761     Philippians46      1-0
# 5762  Chesswizard_2007      1-0
# 5763     MagnusCarlsen  1/2-1/2
# 5764  Chesswizard_2007      1-0
#
#                                         CurrentPosition Timezone  ECO  ...  \
# 0     8/pp5p/1k1pN1pB/1Q1P4/3q2n1/2N5/PPP2PPP/6K1 b - -      UTC  B06  ...
# 1     2N5/1r2k2p/2p1P1q1/p1P1Qp2/5p2/P1Br1P2/1P4PP/4...      UTC  E42  ...
# 2          r6k/pq3pQp/1p6/3bPN2/8/8/1PP3PP/3RR1K1 b - -      UTC  C67  ...
# 3          4r1k1/1p1n1Nr1/p2P2P1/7Q/5P1P/8/PP5K/8 b - -      UTC  C04  ...
# 4                8/3N1pbk/6pp/3Q4/P4P2/8/r2r4/6K1 w - -      UTC  A45  ...
# ...                                                 ...      ...  ...  ...
# 5760     6k1/pp4b1/2p4p/3p4/3P3q/1PN1r3/P5Q1/5RK1 w - -      UTC  D52  ...
# 5761           8/3R2k1/5bpp/p7/1p4p1/1P4P1/P6P/7K b - -      UTC  E60  ...
# 5762       6k1/r2q1p1p/P3pQp1/8/R2p4/8/5PP1/1R4K1 b - -      UTC  B52  ...
# 5763                       8/8/7p/7P/3b4/6k1/8/7K w - -      UTC  A70  ...
# 5764  3r2k1/2qrbp1p/pp4p1/n1p1PnP1/2P1N3/P1QPP2R/1B4...      UTC  A13  ...
#
#        UTCTime WhiteElo BlackElo  TimeControl  \
# 0     18:11:36     2862     1200      1500+25
# 1     18:12:05     2862     1702      1500+25
# 2     18:13:04     2862     1200      1500+25
# 3     18:11:52     2862     1200      1500+25
# 4     18:12:53     2862     2360      1500+25
# ...        ...      ...      ...          ...
# 5760  21:55:20     3034     3279          180
# 5761  21:59:47     3281     2967          180
# 5762  22:05:27     3284     3031          180
# 5763  22:09:51     3036     3279          180
# 5764  22:14:06     3282     3033          180
#
#                              Termination StartTime     EndDate   EndTime  \
# 0         MagnusCarlsen won by checkmate  18:11:36  2014.12.14  18:37:13
# 1       MagnusCarlsen won by resignation  18:12:05  2014.12.14  18:43:33
# 2         MagnusCarlsen won by checkmate  18:13:04  2014.12.14  18:56:09
# 3       MagnusCarlsen won by resignation  18:11:52  2014.12.14  19:05:52
# 4     stepanosinovsky won by resignation  18:12:53  2014.12.14  19:12:15
# ...                                  ...       ...         ...       ...
# 5760    MagnusCarlsen won by resignation  21:55:20  2024.09.21  21:59:43
# 5761    MagnusCarlsen won by resignation  21:59:47  2024.09.21  22:05:24
# 5762    MagnusCarlsen won by resignation  22:05:27  2024.09.21  22:09:43
# 5763             Game drawn by stalemate  22:09:51  2024.09.21  22:13:57
# 5764    MagnusCarlsen won by resignation  22:14:06  2024.09.21  22:16:10
#
#                                               Link  \
# 0        https://www.chess.com/game/live/998800720
# 1        https://www.chess.com/game/live/998800982
# 2        https://www.chess.com/game/live/998802049
# 3        https://www.chess.com/game/live/998800852
# 4        https://www.chess.com/game/live/998801568
# ...                                            ...
# 5760  https://www.chess.com/game/live/120694800057
# 5761  https://www.chess.com/game/live/120694838141
# 5762  https://www.chess.com/game/live/120695400175
# 5763  https://www.chess.com/game/live/120695436813
# 5764  https://www.chess.com/game/live/120695988951
#
#                                                   Moves
# 0     e4 g6 Nf3 d6 d4 Bg7 Bc4 Bg4 Bxf7+ Kxf7 Ng5+ Ke...
# 1     d4 Nf6 c4 e6 Nc3 Bb4 e3 c5 Ne2 d5 a3 Bxc3+ Nxc...
# 2     e4 e5 Nf3 Nc6 Bb5 Nf6 O-O Nxe4 d4 Nd6 Bg5 Be7 ...
# 3     d4 e6 e4 d5 Nd2 Nc6 Ngf3 Nf6 e5 Nd7 Bd3 f6 exf...
# 4     d4 Nf6 Bg5 c5 d5 Ne4 Bc1 e6 c4 b5 cxb5 Qa5+ Nd...
# ...                                                 ...
# 5760  d4 d5 Nf3 e6 c4 c6 Nc3 Nf6 Bg5 Nbd7 e3 h6 Bh4 ...
# 5761  d4 Nf6 c4 g6 g3 d5 cxd5 c6 Bg2 cxd5 Nc3 Bg7 e3...
# 5762  e4 c5 Nf3 d6 Bb5+ Bd7 a4 Nf6 d3 g6 O-O Bg7 e5 ...
# 5763  d4 e6 c4 c5 d5 exd5 cxd5 d6 Nc3 g6 e4 Bg7 Nf3 ...
# 5764  e3 d5 c4 e6 Nf3 Nf6 b3 Be7 Bb2 O-O Nc3 b6 g3 d...
#
# [5765 rows x 22 columns]

# %% [markdown]
# ###Drop some Unnecessary Data

# %%
df1 = df.drop(columns=['Round', 'Site','Timezone','ECO'])
df1
# Out:
#            Event        Date             White             Black   Result  \
# 0     Live Chess  2014.12.14     MagnusCarlsen       RainnWilson      1-0
# 1     Live Chess  2014.12.14     MagnusCarlsen          solskytz      1-0
# 2     Live Chess  2014.12.14     MagnusCarlsen      Tildenbeatsu      1-0
# 3     Live Chess  2014.12.14     MagnusCarlsen            mtmnfy      1-0
# 4     Live Chess  2014.12.14     MagnusCarlsen   stepanosinovsky      0-1
# ...          ...         ...               ...               ...      ...
# 5760  Live Chess  2024.09.21  Chesswizard_2007     MagnusCarlsen      0-1
# 5761  Live Chess  2024.09.21     MagnusCarlsen     Philippians46      1-0
# 5762  Live Chess  2024.09.21     MagnusCarlsen  Chesswizard_2007      1-0
# 5763  Live Chess  2024.09.21  Chesswizard_2007     MagnusCarlsen  1/2-1/2
# 5764  Live Chess  2024.09.21     MagnusCarlsen  Chesswizard_2007      1-0
#
#                                         CurrentPosition  \
# 0     8/pp5p/1k1pN1pB/1Q1P4/3q2n1/2N5/PPP2PPP/6K1 b - -
# 1     2N5/1r2k2p/2p1P1q1/p1P1Qp2/5p2/P1Br1P2/1P4PP/4...
# 2          r6k/pq3pQp/1p6/3bPN2/8/8/1PP3PP/3RR1K1 b - -
# 3          4r1k1/1p1n1Nr1/p2P2P1/7Q/5P1P/8/PP5K/8 b - -
# 4                8/3N1pbk/6pp/3Q4/P4P2/8/r2r4/6K1 w - -
# ...                                                 ...
# 5760     6k1/pp4b1/2p4p/3p4/3P3q/1PN1r3/P5Q1/5RK1 w - -
# 5761           8/3R2k1/5bpp/p7/1p4p1/1P4P1/P6P/7K b - -
# 5762       6k1/r2q1p1p/P3pQp1/8/R2p4/8/5PP1/1R4K1 b - -
# 5763                       8/8/7p/7P/3b4/6k1/8/7K w - -
# 5764  3r2k1/2qrbp1p/pp4p1/n1p1PnP1/2P1N3/P1QPP2R/1B4...
#
#                                                  ECOUrl     UTCDate   UTCTime  \
# 0     https://www.chess.com/openings/Modern-Defense-...  2014.12.14  18:11:36
# 1     https://www.chess.com/openings/Nimzo-Indian-De...  2014.12.14  18:12:05
# 2     https://www.chess.com/openings/Ruy-Lopez-Openi...  2014.12.14  18:13:04
# 3     https://www.chess.com/openings/French-Defense-...  2014.12.14  18:11:52
# 4     https://www.chess.com/openings/Trompowsky-Atta...  2014.12.14  18:12:53
# ...                                                 ...         ...       ...
# 5760  https://www.chess.com/openings/Queens-Gambit-D...  2024.09.21  21:55:20
# 5761  https://www.chess.com/openings/Kings-Indian-De...  2024.09.21  21:59:47
# 5762  https://www.chess.com/openings/Sicilian-Defens...  2024.09.21  22:05:27
# 5763  https://www.chess.com/openings/Benoni-Defense-...  2024.09.21  22:09:51
# 5764  https://www.chess.com/openings/English-Opening...  2024.09.21  22:14:06
#
#       WhiteElo  BlackElo TimeControl                         Termination  \
# 0         2862      1200     1500+25      MagnusCarlsen won by checkmate
# 1         2862      1702     1500+25    MagnusCarlsen won by resignation
# 2         2862      1200     1500+25      MagnusCarlsen won by checkmate
# 3         2862      1200     1500+25    MagnusCarlsen won by resignation
# 4         2862      2360     1500+25  stepanosinovsky won by resignation
# ...        ...       ...         ...                                 ...
# 5760      3034      3279         180    MagnusCarlsen won by resignation
# 5761      3281      2967         180    MagnusCarlsen won by resignation
# 5762      3284      3031         180    MagnusCarlsen won by resignation
# 5763      3036      3279         180             Game drawn by stalemate
# 5764      3282      3033         180    MagnusCarlsen won by resignation
#
#      StartTime     EndDate   EndTime  \
# 0     18:11:36  2014.12.14  18:37:13
# 1     18:12:05  2014.12.14  18:43:33
# 2     18:13:04  2014.12.14  18:56:09
# 3     18:11:52  2014.12.14  19:05:52
# 4     18:12:53  2014.12.14  19:12:15
# ...        ...         ...       ...
# 5760  21:55:20  2024.09.21  21:59:43
# 5761  21:59:47  2024.09.21  22:05:24
# 5762  22:05:27  2024.09.21  22:09:43
# 5763  22:09:51  2024.09.21  22:13:57
# 5764  22:14:06  2024.09.21  22:16:10
#
#                                               Link  \
# 0        https://www.chess.com/game/live/998800720
# 1        https://www.chess.com/game/live/998800982
# 2        https://www.chess.com/game/live/998802049
# 3        https://www.chess.com/game/live/998800852
# 4        https://www.chess.com/game/live/998801568
# ...                                            ...
# 5760  https://www.chess.com/game/live/120694800057
# 5761  https://www.chess.com/game/live/120694838141
# 5762  https://www.chess.com/game/live/120695400175
# 5763  https://www.chess.com/game/live/120695436813
# 5764  https://www.chess.com/game/live/120695988951
#
#                                                   Moves
# 0     e4 g6 Nf3 d6 d4 Bg7 Bc4 Bg4 Bxf7+ Kxf7 Ng5+ Ke...
# 1     d4 Nf6 c4 e6 Nc3 Bb4 e3 c5 Ne2 d5 a3 Bxc3+ Nxc...
# 2     e4 e5 Nf3 Nc6 Bb5 Nf6 O-O Nxe4 d4 Nd6 Bg5 Be7 ...
# 3     d4 e6 e4 d5 Nd2 Nc6 Ngf3 Nf6 e5 Nd7 Bd3 f6 exf...
# 4     d4 Nf6 Bg5 c5 d5 Ne4 Bc1 e6 c4 b5 cxb5 Qa5+ Nd...
# ...                                                 ...
# 5760  d4 d5 Nf3 e6 c4 c6 Nc3 Nf6 Bg5 Nbd7 e3 h6 Bh4 ...
# 5761  d4 Nf6 c4 g6 g3 d5 cxd5 c6 Bg2 cxd5 Nc3 Bg7 e3...
# 5762  e4 c5 Nf3 d6 Bb5+ Bd7 a4 Nf6 d3 g6 O-O Bg7 e5 ...
# 5763  d4 e6 c4 c5 d5 exd5 cxd5 d6 Nc3 g6 e4 Bg7 Nf3 ...
# 5764  e3 d5 c4 e6 Nf3 Nf6 b3 Be7 Bb2 O-O Nc3 b6 g3 d...
#
# [5765 rows x 18 columns]

# %% [markdown]
# ###Describe The DataFrame

# %%
df1.describe()
# Out:
#           WhiteElo     BlackElo
# count  5765.000000  5765.000000
# mean   3113.661232  3106.661925
# std     203.361539   233.145598
# min    1186.000000   259.000000
# 25%    3019.000000  3017.000000
# 50%    3168.000000  3166.000000
# 75%    3262.000000  3260.000000
# max    3459.000000  3455.000000

# %% [markdown]
# ###Find Data type of every column in DataFrame

# %%
df1.dtypes
# Out:
# Event              object
# Date               object
# White              object
# Black              object
# Result             object
# CurrentPosition    object
# ECOUrl             object
# UTCDate            object
# UTCTime            object
# WhiteElo            int64
# BlackElo            int64
# TimeControl        object
# Termination        object
# StartTime          object
# EndDate            object
# EndTime            object
# Link               object
# Moves              object
# dtype: object

# %% [markdown]
# ###Find columns Header in DataFrame

# %%
df1.columns
# Out:
# Index(['Event', 'Date', 'White', 'Black', 'Result', 'CurrentPosition',
#        'ECOUrl', 'UTCDate', 'UTCTime', 'WhiteElo', 'BlackElo', 'TimeControl',
#        'Termination', 'StartTime', 'EndDate', 'EndTime', 'Link', 'Moves'],
#       dtype='object')

# %% [markdown]
# ###Change datatype for data analysis requiredment

# %%
def ob_to_date(data):
  for i in data:
    df1[i] = pd.to_datetime(df[i])

def ob_to_time(data):
  for i in data:
    df1[i] = pd.to_datetime(df[i])

def ob_to_str(data):
  for i in data:
    df1[i] = df1[i].astype("string")
ob_to_str(['Event', 'White', 'Black', 'Result', 'ECOUrl','Termination','Link', 'Moves'])
ob_to_date(['Date','UTCDate','EndDate'])
ob_to_time(['UTCTime','StartTime', 'EndTime'])
# Out:
# <ipython-input-27-57bd892b0b5a>:7: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df1[i] = pd.to_datetime(df[i])
# <ipython-input-27-57bd892b0b5a>:7: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df1[i] = pd.to_datetime(df[i])
# <ipython-input-27-57bd892b0b5a>:7: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df1[i] = pd.to_datetime(df[i])

# %% [markdown]
# ###To find data types are change or not

# %%
df1.dtypes
# Out:
# Event              string[python]
# Date               datetime64[ns]
# White              string[python]
# Black              string[python]
# Result             string[python]
# CurrentPosition            object
# ECOUrl             string[python]
# UTCDate            datetime64[ns]
# UTCTime            datetime64[ns]
# WhiteElo                    int64
# BlackElo                    int64
# TimeControl                object
# Termination        string[python]
# StartTime          datetime64[ns]
# EndDate            datetime64[ns]
# EndTime            datetime64[ns]
# Link               string[python]
# Moves              string[python]
# dtype: object

# %% [markdown]
# ###Here we find Magnus's pieces colour (White or Black) and Magnus game results (Win, Lose and Draw) from process on "Result" column

# %%
l1 = []
l2 = []
l3 = []
for i in range(len(df1)):
  l1.append((df1['White'][i],df1['Result'][i][0], df1['Black'][i],df1['Result'][i][2]))
for i in range(len(df1)):
  if (l1[i][0] == 'MagnusCarlsen' and l1[i][1] == '1'):
    t3 = ('White','win')
  elif (l1[i][0] == 'MagnusCarlsen' and l1[i][1] == '0'):
    t3 = ('White','lose')
  elif (l1[i][2] == 'MagnusCarlsen' and l1[i][-1] == '1'):
    t3 = ('Black','win')
  elif (l1[i][2] == 'MagnusCarlsen' and l1[i][-1] == '0'):
    t3 = ('Black','lose')
  else:
    if l1[i][0] == 'MagnusCarlsen':
      t3 = ('White','Draw')
    else:
      t3 = ('Black','Draw')
  l2.append(t3[0])
  l3.append(t3[1])
df1["magnus's pieces"] = l2
df1["magnus results"] = l3

# %% [markdown]
# ###We collect chess openings from 'ECOUrl' column then Drop 'ECOUrl'

# %%
df1['ECOUrl'][0]
# Out:
# 'https://www.chess.com/openings/Modern-Defense-Bishop-Attack-3...d6-4.Nf3'

# %%
df1['ECOUrl'] = df1['ECOUrl'].map(lambda x: x.split('/'))

# %%
l4 = df1['ECOUrl'].map(lambda x: x[-1])
l4 = l4.map(lambda x: x.split('.'))
l4 = l4.map(lambda x: x[0].split('-'))
l4 = l4.map(lambda x: ' '.join(x))
df1['chess openings'] = l4
df1 = df1.drop(columns=['ECOUrl'])
df1['chess openings']
# Out:
# 0                          Modern Defense Bishop Attack 3
# 1       Nimzo Indian Defense Hubner Rubinstein Variati...
# 2            Ruy Lopez Opening Berlin lHermet Variation 6
# 3               French Defense Tarrasch Guimard Main Line
# 4                                     Trompowsky Attack 2
#                               ...
# 5760         Queens Gambit Declined Modern Knight Defense
# 5761                                 Kings Indian Defense
# 5762                   Sicilian Defense Canal Main Line 4
# 5763            Benoni Defense Modern Classical Variation
# 5764         English Opening Neo Catalan Defense Declined
# Name: chess openings, Length: 5765, dtype: object

# %%
openings = set(df1['chess openings'])
# openings
len(openings)
# Out:
# 1316

# %% [markdown]
# ###Find Total time of Game play

# %%
df1['EndTime'][0]
# Out:
# Timestamp('2024-10-04 18:37:13')

# %%
df1['StartTime'][0]
# Out:
# Timestamp('2024-10-04 18:11:36')

# %%
df1['Time difference'] = df1['EndTime'] - df1['StartTime']
df1['Time difference']
# Out:
# 0      0 days 00:25:37
# 1      0 days 00:31:28
# 2      0 days 00:43:05
# 3      0 days 00:54:00
# 4      0 days 00:59:22
#              ...
# 5760   0 days 00:04:23
# 5761   0 days 00:05:37
# 5762   0 days 00:04:16
# 5763   0 days 00:04:06
# 5764   0 days 00:02:04
# Name: Time difference, Length: 5765, dtype: timedelta64[ns]

# %% [markdown]
# ###Convert time control in second to minutes like
# *   180 to 3 (3 minutes Blitz game)
# *   180+1 to 3|1 (3 minutes and 1 second increment in Blitz game)

# %%
l5 = set(df1['TimeControl'])
l5
# Out:
# {'1500+25',
#  '180',
#  '180+1',
#  '180+2',
#  '300',
#  '300+1',
#  '300+2',
#  '60',
#  '60+1',
#  '600',
#  '600+2',
#  '900',
#  '900+2',
#  '900+3'}

# %%
D = {'1500+25': "25|25",
     '180':"3",
     '180+1':'3|1',
     '180+2':'3|2',
     '300':'5',
     '300+1':'5|1',
     '300+2':'5|2',
     '60':'1',
     '60+1':'1|1',
     '600':'10',
     '600+2':'10|2',
     '900':'15',
     '900+2':'15|2',
     '900+3':'15|3'}
l6 = []
for i in df1['TimeControl']:
  l6.append(D[i])
df1['TimeControl'] = l6

# %% [markdown]
# ###Save DataFrame in Excle File

# %%
df1.to_excel('/content/sample_data/magnuscarlsen_gamesplay_dataprocessing.xlsx')
